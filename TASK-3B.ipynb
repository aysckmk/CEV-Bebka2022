# %% [markdown]
# <a href="https://colab.research.google.com/github/aysckmk/BLPS254/blob/main/TASK-3B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data_all = pd.read_csv("MRI_and_CDRinfo_Values_X_train.csv")
data_labels = pd.read_csv("CDR_Values_y_train.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (22,24,41,46,48,51,90,91,92,93,94,95,96,97,98,99,100,167,205,208,210,213,216,219,221,223,225,227,229,231,235,237,239,241,243,245,247,249,251,253,255,365,380,382,384,402,404,406,551,634,651,654,659,689,770,776,900,908,943,946,964,965,974,1176) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data_all
# Out:
#       Unnamed: 0  Unnamed: 0.1  index_x    NACCID_x  NACCADC_x PACKET  \
# 0           1970          1970   116428  NACC831508       6518      I
# 1           1146          1146   110463  NACC719761       6499      I
# 2            675           675   106548  NACC979197       6061      F
# 3           1268          1268   111371  NACC917131       6499      I
# 4           2323          2323   161286  NACC056098       9661      F
# ...          ...           ...      ...         ...        ...    ...
# 1583         984           984   109131  NACC467810       6499      I
# 1584        1325          1325   111836  NACC015713       6518      I
# 1585         788           788   107627  NACC172271       6499      I
# 1586         195           195    33729  NACC692052       2096      I
# 1587        1206          1206   110911  NACC817729       6499      I
#
#       FORMVER  VISITMO  VISITDAY  VISITYR  ...  RSUPPARM  RSUPTEM  RSUPTEMM  \
# ...

# %%
data_labels
# Out:
#       Unnamed: 0  CDRGLOB
# 0           1970        0
# 1           1146        0
# 2            675        0
# 3           1268        2
# 4           2323        0
# ...          ...      ...
# 1583         984        1
# 1584        1325        1
# 1585         788        2
# 1586         195        1
# 1587        1206        0
#
# [1588 rows x 2 columns]

# %%
data_all['HIPPOVOL']
# Out:
# 0       5.1960
# 1       6.8940
# 2       6.2860
# 3       5.5890
# 4       7.4100
#          ...
# 1583    7.9400
# 1584    5.3273
# 1585    6.5270
# 1586    5.3400
# 1587    7.6090
# Name: HIPPOVOL, Length: 1588, dtype: float64

# %%
data_labels.describe()
# Out:
#         Unnamed: 0      CDRGLOB      HIP_VOL
# count  1588.000000  1588.000000  1588.000000
# mean   1246.960957     0.751259     5.951227
# std     710.158370     0.825227     0.925175
# min       0.000000     0.000000     2.971900
# 25%     596.750000     0.000000     5.346000
# 50%    1362.500000     1.000000     5.980000
# 75%    1849.250000     1.000000     6.600250
# max    2419.000000     3.000000     9.696500

# %%
import matplotlib.pyplot as plt
plt.hist(data_all['HIPPOVOL'],bins=100)
plt.grid(True)

# %%
data_labels.groupby('CDRGLOB').agg({
    'HIP_VOL': ['mean','std']
}).plot(kind='bar')

# %%
data_labels.groupby('CDRGLOB')[['HIP_VOL']].describe()
# Out:
#         HIP_VOL                                                          \
#           count      mean       std     min       25%      50%      75%
# CDRGLOB
# 0         721.0  6.304869  0.757105  4.1340  5.781000  6.25570  6.84860
# 1         607.0  5.839063  0.866157  3.0209  5.264750  5.81930  6.40115
# 2         194.0  5.323365  0.974990  2.9719  4.579325  5.35495  5.97160
# 3          66.0  4.965071  1.031115  3.1056  4.347850  4.84365  5.43490
#
#
#             max
# CDRGLOB
# 0        9.6965
# 1        8.9606
# 2        7.9945
# 3        7.7950

# %%
data_labels["HYPERTEN"]=data_all["HYPERTEN"]

# %%
data_labels["GENDER"]=data_all["SEX"]

# %%
data_labels["ANXIETY"]=data_all["ANXIETY"]

# %%
data_labels["CANCER"]=data_all["CANCER"]

# %%
data_labels["BRN_VOL"]=data_all["NACCBRNV"]

# %%
from numpy.ma.core import mean
data_labels.pivot_table(('HIP_VOL','BRN_VOL','CANCER'), index='CDRGLOB', columns=['GENDER','HYPERTEN',],aggfunc=mean)
# Out:
#               BRN_VOL                                                      \
# GENDER              1
# HYPERTEN           -4            0            1            2            9
# CDRGLOB
# 0         1145.571818  1116.790055  1063.644248  1091.452571          NaN
# 1         1080.932600  1081.000808  1047.664492  1064.387556  1042.051333
# 2         1136.895000  1068.077333  1034.336373  1085.739000          NaN
# 3         1100.350000  1035.752833  1004.331261   979.972000          NaN
#
#                                                                         ...  \
# GENDER              2                                                   ...
# HYPERTEN           -4            0           1           2           9  ...
# CDRGLOB                                                                 ...
# 0          982.360690  1023.922856  952.213005  982.859182  975.231333  ...
# 1          931.195714   960.242940  927.268616  944.668750  879.562333  ...
# ...
