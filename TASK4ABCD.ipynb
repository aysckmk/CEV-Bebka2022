# %% [markdown]
# <a href="https://colab.research.google.com/github/aysckmk/BLPS254/blob/main/TASK4ABCD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Temporary_data3_-_Copy.xlsx")
data.head()
# Out:
#    SEX  EDUC  MARISTAT  INDEPEND  RESIDENC  NACCFAM  ANYMEDS  SMOKYRS  \
# 0    2    18         1         1         1        1        1        0
# 1    1    11         1         1         1        1        1        0
# 2    2    16         1         1         1        1        1       10
# 3    1    14         1         1         1        0        1        0
# 4    1    16         1         1         2        0        1       50
#
#    NACCTBI  DIABETES  ...   RSUPFR  RSUPFRM  RSUPPAR  RSUPPARM  RSUPTEM  \
# 0        0         0  ...  27.9038   2.2157  10.3481    1.7014  13.4250
# 1        0         0  ...  29.0600   2.6900   9.2500    1.6300  14.8800
# 2        0         1  ...  33.0000   2.5400  13.6900    1.5600  16.2300
# 3        0         1  ...  31.6800   2.4100   9.6400    1.4500  15.1100
# 4        0         0  ...  28.0631   1.9501   9.1125    1.0427  13.3763
#
#    RSUPTEMM  RSUPMAR  RSUPMARM  RTRTEM  RTRTEMM
# 0    1.7419   9.8700    1.6792  0.8906   1.1947
# ...

# %% [markdown]
# 4A)Please present a descriptive statistics analysis to provide a general understanding of the dataset

# %%
data.describe()
# Out:
#                SEX         EDUC     MARISTAT     INDEPEND     RESIDENC  \
# count  1354.000000  1354.000000  1354.000000  1354.000000  1354.000000
# mean      1.573855    15.223781     1.658789     1.316100     1.112999
# std       0.494698     3.418699     1.136754     0.598538     0.360372
# min       1.000000     0.000000     1.000000     1.000000     1.000000
# 25%       1.000000    12.000000     1.000000     1.000000     1.000000
# 50%       2.000000    16.000000     1.000000     1.000000     1.000000
# 75%       2.000000    18.000000     2.000000     2.000000     1.000000
# max       2.000000    25.000000     6.000000     4.000000     4.000000
#
#            NACCFAM      ANYMEDS      SMOKYRS      NACCTBI     DIABETES  ...  \
# count  1354.000000  1354.000000  1354.000000  1354.000000  1354.000000  ...
# mean      0.631462     0.952733     9.754801     0.127031     0.192762  ...
# std       0.482586     0.212289    14.351222     0.333131     0.432160  ...
# ...

# %% [markdown]
# 4B)Please provide the visual illustrations of the dataset that will demonstrate the insightful distributions with respect to the target column (CDRGLOB: the level of the Alzheimer Disease -AD)

# %%
x = data["CERECSF"]
y = data["TEMPCOR"]
labels = data["CDRGLOB"]
plt.scatter(x,y, cmap='viridis',c=labels, alpha=0.5)
plt.xlabel('CERECSF Level')
plt.ylabel('TEMPCOR Index')
plt.title('TEMPCOR-CERECSF Scatter')
plt.colorbar()
plt.show()

# %%
x = data["HIPPOVOL"]
y = data["INDEPEND"]
labels = data["CDRGLOB"]
plt.scatter(x,y, cmap='viridis',c=labels, alpha=0.5)
plt.xlabel('Hippovol Level')
plt.ylabel('Independ Index')
plt.title('HIPPOVOL-INDEPEND Scatter')
plt.colorbar()
plt.show()

# %% [markdown]
# 4C)Please provide a correlation analysis between two different variables/features and argue for the analysis outputs.

# %%
data['NEW'] = (data['CERECSF'] * data['INDEPEND'] )

# %%
data.groupby('CDRGLOB')[['NEW']].mean()
# Out:
#                 NEW
# CDRGLOB
# 0        278.610009
# 1        407.892431
# 2        652.870461
# 3        988.460830

# %%
data.corr().iloc[16][-1]
# Out:
# 0.6805385833505607

# %% [markdown]
# 4D) Please provide several pivot tables for insightful illustrations both via tables and figures.

# %%
pcut= pd.qcut(data["RSUPFRM"], 4)
data.pivot_table("CERECSF", index="CDRGLOB", columns=pcut)
# Out:
# RSUPFRM  (0.901, 1.988]  (1.988, 2.198]  (2.198, 2.376]  (2.376, 4.06]
# CDRGLOB
# 0            277.393366      271.353510      265.667508     287.083632
# 1            298.734292      296.472619      298.373190     295.450092
# 2            327.092597      326.271217      336.543000     331.633778
# 3            320.085100      360.018250      346.894250     328.264000

# %%
data.pivot_table("CERECSF", index="CDRGLOB", columns=pcut, aggfunc="count")
# Out:
# RSUPFRM  (0.901, 1.988]  (1.988, 2.198]  (2.198, 2.376]  (2.376, 4.06]
# CDRGLOB
# 0                    93             143             179            231
# 1                   154             134             121             87
# 2                    72              46              29             18
# 3                    20              16               8              3

# %%
data.pivot_table("CERECSF", index=["CDRGLOB"], columns=pcut).plot(kind="bar")
plt.show()
